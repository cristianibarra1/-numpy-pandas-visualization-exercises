# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import math
import numpy as np

# %%
xs = range(-100,100)
y = [(x ** 2 - x + 2) for x in xs]
plt.figure(figsize=(14, 6))
plt.plot(xs, y)
plt.annotate('Right Here !', xy=(0, 0), xytext=(-40, 4000), fontsize=15,arrowprops={'facecolor': 'black'})
plt.show()

# %%
# y = √x
# y = x^3
# y = 1/(x+1)
# y = 2^x
plt.suptitle(f'x = {x2}')

x2 = range(0, 10)
y1 = [math.sqrt(x) for x in x2]
y2 = [x ** 3 for x in x2]
y3 = [1/(x+1) for x in x2]
y4 = [2 ** x for x in x2]
plt.subplot(221)
plt.plot(x2, y1)
plt.subplot(222)
plt.plot(x2, y2)
plt.subplot(223)
plt.plot(x2, y3)
plt.subplot(224)
plt.plot(x2, y4)
plt.show()

# %%
# Combine the figures you created in the last step into one large figure with 4 subplots.
plt.figure(figsize=(14, 6))
plt.plot(x2, y1)
plt.plot(x2, y2)
plt.plot(x2, y3)
plt.plot(x2, y4)
plt.show()

# %%
# Combine the figures you created in the last step into one figure where each of the 4 equations has 
# a different color for the points. 
# Be sure to include a legend and an appropriate title for the figure.
plt.scatter(x2, y1, label='sqrt x', color='red')
plt.plot(x2, y1, color='red')
plt.scatter(x2, y2, label='x^3', color='green')
plt.plot(x2, y2, color='green')
plt.scatter(x2, y3, label='y = 1/(x+1)', color='blue')
plt.plot(x2, y3, color='blue')
plt.scatter(x2, y4, label='2^x', color='purple')
plt.plot(x2, y4, color='black')
plt.legend()
plt.show()
